# %%
import numpy as np
import pandas as pd
import cPickle as pkl
import matplotlib.pyplot as plt
from src.create_and_evaluate_model import ModelMaker as MM

# %matplotlib inline
# %autoreload 2

# %%
root = "path/to/project"
image_dir = "data/images/"

seek_mvp = MM(root, image_dir)

# %%
seek_mvp.process_images_and_train_model()

# %%
seek_mvp.evaluate_model()

# %%
seek_mvp.display_report()
# Out:
# Training set cross validation metrics:
#
# Log loss:
# [-0.54614142 -0.75931151 -0.95256505]
#
# Accuracy:
# [ 0.76923077  0.75        0.66666667]
#
# #########
#
# Test set metrics:
#
# Test set value counts:
# stand    14
# sit      11
# lie       8
# Name: label, dtype: int64
#
#
# lie
# sit
# stand
#
# Test Confusion Matrix:
# [[ 3  4  1]
#  [ 1  8  2]
#  [ 0  3 11]]
#
# Percentage True in each predicted class
# [[ 37.5   50.    12.5 ]
#  [  9.09  72.73  18.18]
#  [  0.    21.43  78.57]]

# %%
# # save the classifier
# with open('data/multiclass_log_reg.pkl', 'wb') as fid:
#     pkl.dump(model, fid)

# # # load it again
# # with open('data/multiclass_log_reg.pkl', 'rb') as fid:
# #     model = cPickle.load(fid)
